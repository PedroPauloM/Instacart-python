# %%
# Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# %%
df_ords_prods_merged = pd.read_pickle(r'/Users/pedropaulo/Desktop/Tasks CF/Instacart Basket Analysis/Data/Prepared Data/orders_products_merged.pkl')

# %%
# Create a subset
df_ords_prods_merged = df_ords_prods_merged[:1000000]

# %%
df_ords_prods_merged
# Out:
#         order_id  user_id  order_number  orders_day_of_week  \
# 0        2539329        1             1                   2
# 1        2398795        1             2                   3
# 2         473747        1             3                   3
# 3        2254736        1             4                   4
# 4         431534        1             5                   4
# ...          ...      ...           ...                 ...
# 999995    671090    44972             3                   4
# 999996   3111007    44972             4                   4
# 999997   1532419    44972             5                   6
# 999998   1463801    44972             6                   6
# 999999   2041514    44972             7                   1
#
#         order_hour_of_day  days_since_last_order  product_id  \
# 0                       8                    NaN         196
# 1                       7                   15.0         196
# ...

# %%
df.shape
# Out:
# (1000000, 14)

# %%
# Define a function

def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# Apply the function

df.apply(price_label, axis=1)
# Out:
# 0         Mid-range product
# 1         Mid-range product
# 2         Mid-range product
# 3         Mid-range product
# 4         Mid-range product
#                 ...
# 999995    Mid-range product
# 999996    Mid-range product
# 999997    Mid-range product
# 999998    Mid-range product
# 999999    Mid-range product
# Length: 1000000, dtype: object

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
# Checking values

df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    666122
# Low-range product    333878
# Name: price_range_loc, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %%
# Checking Frequency Days

# %%
df['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    193495
# 1    185912
# 2    130640
# 6    130593
# 5    128719
# 3    116210
# 4    114431
# Name: orders_day_of_week, dtype: int64

# %% [markdown]
# Observations: The two busiest days are 0 (Saturday) and 1 (Sunday). The two slowest days are 4 (Wednesday) and 3 (Tuesday)

# %%
result = []

for value in df_ords_prods_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df_ords_prods_merged['busiest_day'] = result
# Out:
# /var/folders/vy/7wyzrqvj1sbcxy4f8twmkdwc0000gn/T/ipykernel_4702/1579233956.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ords_prods_merged['busiest_day'] = result

# %%
df_ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    692074
# Busiest day       193495
# Least busy        114431
# Name: busiest_day, dtype: int64

# %%
# Creating empty shell and Adding new labels

result2 = []

for value in df_ords_prods_merged['orders_day_of_week']:
  if value == 0 or value ==1:
    result2.append('Busiest days')
  elif value == 4 or value == 3:
    result2.append('Slowest days')
  else:
    result2.append('Regularly days')

# %%
# Creating new column 'busiest_days'

df_ords_prods_merged['busiest_days'] = result2
# Out:
# /var/folders/vy/7wyzrqvj1sbcxy4f8twmkdwc0000gn/T/ipykernel_4702/670434676.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ords_prods_merged['busiest_days'] = result2

# %%
#Check
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge     busiest_day  \
# ...

# %%
# Check frequency of values in the "order_hour_of_day" column 
df_ords_prods_merged['order_hour_of_day'].value_counts()
# Out:
# 10    88427
# 11    82605
# 9     81460
# 14    81104
# 13    80734
# 15    80733
# 12    78847
# 16    76941
# 17    61890
# 8     57929
# 18    48299
# 19    37821
# 7     29973
# 20    29843
# 21    25353
# 22    20093
# 23    12029
# 6      9297
# 0      6211
# 1      3136
# 5      2672
# 2      1820
# 4      1490
# 3      1293
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# Observations: The 24 hours of the day can be split into three parts, with each part classified as having either 'Most orders' (hour 10, 11, 9, 14, 13, 15, 12, 16 - from 9am to 4pm), 'Average orders' (hour 17, 8, 18, 19, 20, 7, 21, 22 - from 7am to 8am and from 5pm to 10pm), or 'Fewest orders' (hour 23, 6, 0, 1, 5, 2, 4, 3 - from 11pm to 6am).

# %%
# Creating empty shell and Adding new labels 
hour_of_day = []

for value in df_ords_prods_merged["order_hour_of_day"]:
  if value in [10, 11, 14, 15, 13, 12, 16, 9]:
    hour_of_day.append("Most orders")
  elif value in [23, 6, 0, 1, 5, 2, 4, 3]:
    hour_of_day.append("Fewest orders")
  else:
    hour_of_day.append("Average orders")

# %%
# Add result to dataframe as "busiest_period_of_day" column
df_ords_prods_merged['busiest_period_of_day'] = hour_of_day
# Out:
# /var/folders/vy/7wyzrqvj1sbcxy4f8twmkdwc0000gn/T/ipykernel_4702/4287486884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ords_prods_merged['busiest_period_of_day'] = hour_of_day

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge     busiest_day  \
# ...

# %%
df_ords_prods_merged['busiest_period_of_day'].value_counts()
# Out:
# Most orders       650851
# Average orders    311201
# Fewest orders      37948
# Name: busiest_period_of_day, dtype: int64

# %%
# Export as Pickle File

df_ords_prods_merged.to_pickle(r'/Users/pedropaulo/Desktop/Tasks CF/Instacart Basket Analysis/Data/Prepared Data/orders_products_merged_2.pkl')
